# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
path = '../data/interim/yolact_output/20221117/crop/side/'
fname = '2695_0_846_1016_1100_1561.jpg'
img = Image.open(path + fname)
plt.imshow(img)
